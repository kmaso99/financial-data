# %% [markdown]
# This AI-powered financial chatbot prototype currently only responds to the given set of questions for selected companies and fiscal years

# %% [markdown]
# 1. What is the total revenue?
# 2. What is the net income?
# 3. What is the sum of total assets?
# 4. What is the sum of total liabilities?
# 5. What is the cash flow from operating activities?
# 6. What is the revenue growth (%)?
# 7. What is the net income growth (%)?
# 8. What is the assets growth (%)?
# 9. What is the liabilities growth (%)?
# 10. What is the cash flow from operating activities growth (%)?
# 11. What is the year by year average revenue growth rate (%)?
# 12. What is the year by year average net income growth rate (%)?
# 13. What is the year by year average assets growth rate (%)?
# 14. What is the year by year average liabilities growth rate (%)?
# 15. What is the year by year average cash flow from operating activities rate (%)?

# %%
import pandas as pd
df = pd.read_csv("final_data_report.csv")
df_2 = pd.read_csv("summary_final_report.csv")

# %%
df
# Out:
#    Unnamed: 0.1  Unnamed: 0  Year    Company  Net Income  Total Revenue  \
# 0             0           0  2023  Microsoft       72361         211915
# 1             1           1  2022  Microsoft       72738         198270
# 2             2           2  2021  Microsoft       61271         168088
# 3             3           3  2023      Tesla       14974          96773
# 4             4           4  2022      Tesla       12556          81462
# 5             5           5  2021      Tesla        5519          53823
# 6             6           6  2023      Apple       96995         383285
# 7             7           7  2022      Apple       99803         394328
# 8             8           8  2021      Apple       94680         365817
#
#    Total Assets  Total Liabilities  Cash Flow from Operating Activities  \
# 0        411976             205753                                87582
# 1        364840             198298                                89035
# 2        333779             191791                                76740
# 3        106618              43009                                13256
# 4         82338              36440                                14724
# 5         62131              30548                                11497
# 6        352583             290437                               110543
# 7        352755             302083                               122151
# 8        351002             287912                               104038
#
#    Revenue Growth (%)  Net Income Growth (%)  Assets Growth (%)  \
# 0            0.000000               0.000000           0.000000
# 1           -6.438902               0.520999         -11.441443
# 2          -15.222676             -15.764800          -8.513595
# 3            0.000000               0.000000           0.000000
# 4          -15.821562             -16.147990         -22.772890
# 5          -33.928703             -56.044919         -24.541524
# 6            0.000000               0.000000           0.000000
# 7            2.881146               2.894995           0.048783
# 8           -7.230275              -5.133112          -0.496945
#
#    Liabilities Growth (%)  Cash Flow from Operations Growth(%)
# 0                0.000000                             0.000000
# 1               -3.623276                             0.016590
# 2               -3.281425                            -0.138092
# 3                0.000000                             0.000000
# 4              -15.273547                             0.110742
# 5              -16.169045                            -0.219166
# 6                0.000000                             0.000000
# 7                4.009820                             0.105009
# 8               -4.691095                            -0.148284

# %%
print("Year by Year Average Growth from 2021 to 2023")
df_2
# Out:
# Year by Year Average Growth from 2021 to 2023
#    Unnamed: 0    Company  Revenue Growth (%)  Net Income Growth (%)  \
# 0           0      Apple           -1.449710              -0.746039
# 1           1  Microsoft           -7.220526              -5.081267
# 2           2      Tesla          -16.583422             -24.064303
#
#    Assets Growth (%)  Liabilities Growth (%)  \
# 0          -0.149388               -0.227092
# 1          -6.651679               -2.301567
# 2         -15.771471              -10.480864
#
#    Cash Flow from Operations Growth(%)
# 0                            -0.014425
# 1                            -0.040501
# 2                            -0.036141

# %%
# %run AI_driven_financial_chatbot_prototype.py
# Out:
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Microsoft
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2022
# Please enter your query
#  What is the total revenue?
# The Total Revenue for Microsoft for fiscal year 2022 is $ 198270
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  exit

# %%
# %run AI_driven_financial_chatbot_prototype.py
# Out:
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  abcdefg
# Enter 'Hi' Properly!!!!! by starting the chatbot session again

# %%
# %run AI_driven_financial_chatbot_prototype.py
# Out:
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Apple
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2023
# Please enter your query
#  What is the net income?
# The Net Income for Apple for fiscal year 2023 is $ 96995
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  exit

# %%
# %run AI_driven_financial_chatbot_prototype.py
# Out:
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Tesla
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2021
# Please enter your query
#  What is the sum of total assets?
# The sum of Total Assets for Tesla for fiscal year 2021 is $ 62131
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Apple
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2021
# Please enter your query
#  What is the sum of total liabilities?
# The sum of Total Liabilities for Apple for fiscal year 2021 is $ 287912
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Microsoft
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2023
# Please enter your query
#  What is the cash flow from operating activities?
# The Cash Flow from Operating Activities for Microsoft for fiscal year 2023 is $ 87582
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  exit

# %%
# %run AI_driven_financial_chatbot_prototype.py
# Out:
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Apple
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2022
# Please enter your query
#  What is the revenue growth(%)?
# The Revenue Growth(%) for Apple for fiscal year 2022 is 2.8811(%)
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Tesla
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2021
# Please enter your query
#  What is the net income growth(%)?
# The Net Income Growth(%) for Tesla for fiscal year 2021 is -56.0449(%)
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Microsoft
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2021
# Please enter your query
#  What is the assets growth(%)?
# The Assets Growth(%) for Microsoft for fiscal year 2021 is -8.5136(%)
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Apple
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2022
# Please enter your query
#  What is the liabilities growth(%)?
# The Liabilities Growth(%) for Apple for fiscal year 2022 is 4.0098(%)
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Apple
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2022
# Please enter your query
#  What is the cash flow from operations growth(%)?
# The Cash Flow from Operations Growth(%) for Apple for fiscal year 2022 is 0.105(%)
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  exit

# %%
# %run AI_driven_financial_chatbot_prototype.py
# Out:
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Microsoft
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2023
# Please enter your query
#  What is the year by year average revenue growth rate(%)?
# The Year By Year Average Revenue Growth Rate(%) from 2021 to 2023 for Microsoft is -7.2205(%)
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Tesla
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2022
# Please enter your query
#  What is the year by year average net income growth rate(%)?
# The Year By Year Net Income Revenue Growth Rate(%) from 2021 to 2023 for Tesla is -24.0643(%)
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Apple
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2021
# Please enter your query
#  What is the year by year average assets growth rate(%)?
# The Year By Year Average Assets Growth Rate(%) from 2021 to 2023 for Apple is -0.1494(%)
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Microsoft
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2021
# Please enter your query
#  What is the year by year average assets growth rate(%)?
# The Year By Year Average Assets Growth Rate(%) from 2021 to 2023 for Microsoft is -6.6517(%)
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Apple
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2022
# Please enter your query
#  What is the year by year average liabilities growth rate (%)?
# Sorry, I can only provide information on predefined queries.
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  exit

# %%
# %run AI_driven_financial_chatbot_prototype.py
# Out:
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Apple
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2022
# Please enter your query
#  What is the year by year average liabilities growth rate(%)?
# The Year By Year Average Liabilities Growth Rate(%) from 2021 to 2023 for Apple is -0.2271(%)
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  Hi
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name :  Tesla
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company :  2023
# Please enter your query
#  What is the year by year average cash flow from operations growth rate(%)?
# The Year By Year Average Cash Flow from Operations Growth Rate(%) from 2021 to 2023 for Tesla is -0.0361(%)
# ----------------------------------------------------------------------------
# Enter Hi to start the chatbot session; type 'exit' to quit):  exit
